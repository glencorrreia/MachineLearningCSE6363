# %% [markdown]
# # Part 1 Preparing the Data

# %%
import numpy as np
import math
import matplotlib.pyplot as plt  
from mpl_toolkits.mplot3d import Axes3D
from sklearn import datasets
from itertools import combinations
from itertools import permutations
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split



# %matplotlib notebook

# %%
iris_data = datasets.load_iris()
x = iris_data.data
y = iris_data.target

print(iris_data.target_names)
feature_names = iris_data.feature_names

comb = list(combinations(list(range(4)), 2))
print(comb)
fig = plt.figure(figsize=[8, 10])
for i, g in enumerate(comb):
    
    x_train, x_test, y_train, y_test = train_test_split(x[:,g[0]], x[:,g[1]], test_size=0.1)
    
    #Fit a model
    model = LogisticRegression(multi_class='ovr')
    model.fit(x[:, g], y)

    
    gp = fig.add_subplot(3, 2, i +1) 
    #plt.scatter(x_train ,y_train, c=y, marker='s', cmap='summer')
# plt.scatter(xs, y_1s, "-b", label="x^2")
# plt.sctter(xs, y_2s, "-g", label = "2x + 1")

    #gp.legend(["Training Dataset", "Testing Dataset"], loc ="lower right")

    
    gp.scatter(x_train ,y_train, c=y_train,  edgecolor='k', label="Training Dataset",cmap='summer')
    gp.scatter(x_test, y_test, c=y_test, marker='s',  edgecolor='k', label="Testing Dataset",cmap='summer')
    gp.legend()

    xmin, xmax = gp.get_xlim()
    ymin, ymax = gp.get_ylim()


    gp.set_xlabel(feature_names[g[0]])
    gp.set_xlabel(feature_names[g[1]])
    

    #plt.xlabel('True values')
    #plt.show()
    
#     for k in range(len(iris_data.target_names)):
#         b = model.intercept_[k]
#         weights = model.coef_[k]
#         bias = -b / weights[1]
#         m = -weights[0] / weights[1]
#         gp.axline([0, bias], slope=m)
        
#     gp.set_xlim([xmin, xmax])
#     gp.set_ylim([ymin, ymax])
# Out:
# ['setosa' 'versicolor' 'virginica']
# [(0, 1), (0, 2), (0, 3), (1, 2), (1, 3), (2, 3)]
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# # Part 2 Linear Regression

# %%
feature_names = iris_data.feature_names

per = list(permutations(list(range(4)), 2))
print(per)
fig = plt.figure(figsize=[8, 10])
fig.subplots_adjust(hspace=0.5)
fig.subplots_adjust(wspace=0.5)




for i, g in enumerate(per):
    
    
    #Fit a model
    model = LinearRegression()
    model.fit(x[:, g], y)

    
    gp = fig.add_subplot(4, 3, i +1) 
    
    gp.scatter(x_train ,y_train, c=y_train,  edgecolor='k',cmap='summer')
    gp.scatter(x_test, y_test, c=y_test, marker='s',  edgecolor='k',cmap='summer')


    xmin, xmax = gp.get_xlim()
    ymin, ymax = gp.get_ylim()


    gp.set_xlabel(feature_names[g[0]])
    gp.set_xlabel(feature_names[g[1]])
    
   #Plot decison Boundaries 
    for k in range(len(iris_data.target_names)):
        b = (np.random.rand() * 2) - 1
        m = (np.random.rand() * 2) - 1
        
                
        gp.axline([0, b], slope=m)

        gp.set_xlim([xmin, xmax])
        gp.set_ylim([ymin, ymax])
# Out:
# [(0, 1), (0, 2), (0, 3), (1, 0), (1, 2), (1, 3), (2, 0), (2, 1), (2, 3), (3, 0), (3, 1), (3, 2)]
# <img src="data:image/png;base64,..." width="800">

# %%
# Mean Square Error
def Mean_Square(predictdata, targetingdata):
    return 0.5 * np.sum((predictdata - targetingdata)**2)

#Weight Using Stochastic Gradient Descent
def Stoc_Grad(predictdata, targetdata, grad, alpha=0.01):
    
    Error = predictdata - target
    Change = Error @ grad
    Weight = New - alpha * Error
    
    return Weight

# %%
steps = 100
b_size = 32

#Split data 
x_train, x_test, y_train, y_test = train_test_split(x[:,g[0]], x[:,g[1]], test_size=0.1)

#Split Batch into training dataset
for i in range(0,len(x_train), b_size):
    bx = [x_train[i: i + b_size]]
    print(bx)   
for j in range(0,len(y_train), b_size):
    by = [y_train[j: j + b_size]]
    print(by)
# Out:
# [array([1.3, 1.8, 0.4, 0.2, 1.1, 1.9, 0.2, 2.5, 2.1, 1.3, 2.1, 1.5, 1.8,
#        1.8, 1.5, 0.2, 1.4, 1.5, 1.8, 0.2, 1.3, 2.5, 2.4, 0.2, 0.2, 2.3,
#        2.2, 2.1, 1.6, 2.3, 1.7, 0.2])]
# [array([0.6, 0.2, 2. , 1.5, 0.2, 1.3, 0.1, 1. , 2.4, 0.2, 1.7, 0.3, 0.3,
#        1. , 1.5, 2.3, 0.2, 0.2, 0.1, 0.2, 0.2, 1.3, 2. , 0.2, 1.3, 1. ,
#        1.5, 1.8, 1.3, 0.3, 0.2, 1.6])]
# [array([2. , 1.5, 0.1, 0.2, 1.5, 1.9, 1.8, 2.3, 0.5, 1.5, 0.1, 1.8, 1.4,
#        1.3, 0.3, 2.2, 0.3, 1.2, 0.3, 0.2, 1.9, 2. , 1.9, 1.1, 1.9, 1.3,
#        1. , 2. , 2.4, 0.3, 1.8, 1.5])]
# [array([0.2, 1.6, 1.8, 1.2, 1.3, 1.4, 2.3, 2.3, 1.5, 0.4, 0.2, 0.2, 0.2,
#        0.2, 1.4, 0.2, 0.2, 1.4, 1.3, 0.2, 1. , 1.8, 2. , 2.3, 1. , 1.8,
#        1.4, 1.2, 1.4, 1.3, 2.1, 1.1])]
# [array([2.1, 1.2, 0.4, 0.2, 0.2, 1. , 0.4])]
# [array([4.2, 5.6, 1.3, 1.6, 3.9, 5.3, 1.4, 6. , 5.4, 4.1, 5.5, 4.5, 4.8,
#        4.8, 4.5, 1.3, 4.7, 4.6, 4.9, 1.7, 4.2, 5.7, 5.6, 1.4, 1.6, 5.1,
#        5.6, 5.7, 5.8, 5.9, 4.5, 1.5])]
# ...

# %%
fig = plt.figure(figsize=[8, 16])
for i, k in enumerate(per):
    #Use random weights [w0 , w1] for each modal
    w = np.random.uniform(-1, 1, 2)
    rl = fig.add_subplot(12,1, i+1)
    rl.set_xlabel('AverageError')
    rl.set_ylabel('steps')
    listerror = []
    
    for n in range(steps):
        
        Sum_of_error = 0
        for indexa in range(len(bx)):
            
            #Read each model input and target data batch-wise
            batch_d = bx[indexa][:, k]
            batch_t = by[indexa]
            
            #Predicted target
            predict_batch_t = batch_d @ w
            
            #loss function using mean squar error
            Error_in_batch = Mean_Square(predict_batch_t, batch_t)
            Sum_of_error += Error_in_batch
            
            #Using stocastic gradient descent to get new value for weights
            w = Stoc_Grad(predict_batch_t, batch_t, batch_d, alpha=0.002)
        
        AverageError = Sum_of_error/len(bx)
        Error_avg_list.append(AverageError)
    
    gp.plot(Error_avg_list, np.linspace(1, 100, 100), label=feature_names[k[0]] + ' - ' + feature_names[k[1]])
    gp.legend(loc='best')
            
fig.tight_layout()
#fig.savefig('linear_regression_training_plot.png')
# Out:
# <img src="data:image/png;base64,..." width="800">
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/wm/14w2c7751klgtnkgn1yj14m00000gn/T/ipykernel_40699/3843984802.py in <module>
#      18
#      19             #Predicted target
# ---> 20             predict_batch_t = batch_d @ w
#      21
#      22             #loss function using mean squar error
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 2 is different from 7)

# %% [markdown]
# # L2 Reglarisation

# %%
w_reg = w_non_reg = np.random.uniform(-1, 1, 2)
reg = 1
My_tuple = (5,4)

non_reg_error_sum = 0
reg_error_sum = 0
for index in range(len(bx)):
    batch_d = bx[index][:, My_tuple]
    batch_t = by[index]
    reg_by = batch_d @ w_reg
    nreg_by_ = batch_d @ w_non_reg
    
    #loss function using mean squar error
    reg_error = lst_sq(reg_batch_y_hat, batch_target)
    non_reg_error = lst_sq(non_reg_batch_y_hat, batch_target)

    reg_error_sum += reg_error
    non_reg_error_sum += non_reg_error
    
    final_reg = np.linalg.inv(regularization * np.eye(batch_d.shape[1]) + batch_d.T @ batch_data) @ (batch_d.T @ batch_t)
    final_non_reg = np.linalg.inv(batch_d.T @ batch_d) @ (batch_d.T @ batch_t)
        
avg_r = reg_error_sum/len(bx)
avg_nr = non_reg_error_sum/len(bx)

print('Regularised weight : {} and error : {}'.format(final_reg, avg_r))
print('Non-Regularised weight : {} and error : {}'.format(final_non_reg, avg_nr))
